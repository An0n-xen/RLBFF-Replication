# %%
import os
import time
import asyncio
from typing import Dict, Set
from dotenv import load_dotenv
import pandas as pd
from datasets import load_dataset
from utils.utils import load_processed_ids, save_success
from utils.inference import LLMInferenceClient, ProviderConfig

# %%
load_dotenv()
# Out:
# True

# %%
ds = load_dataset("nvidia/HelpSteer3", "feedback", split="train")

# %%
ds
# Out:
# Dataset({
#     features: ['domain', 'language', 'context', 'response1', 'response2', 'feedback1', 'feedback2'],
#     num_rows: 38782
# })

# %%
PROMPT_TEMPLATE = """
    Feedback: {feedback}

    Generate a list of principles that the response is evaluated against in the feedback.
    For each principle, identify a text span from the feedback relating to this principle and then state whether the text span suggests that the response satisfies the principle yes/no/partially.

    Return it as a json dictionary in the format {{"<principle 1>": "<supporting text span>-<yes/no/partially>", "<principle 2>": "<supporting text span>-<yes/no/partially>".}}
"""

# %%
providers = {
    "hf": ProviderConfig(
        model_name="Qwen/Qwen2.5-72B-Instruct",
        api_key=os.getenv("HF_TOKEN"),
        max_retries=5,
        
    ),
    "groq": ProviderConfig(
        model_name="llama3-70b-8192",
        api_key=os.getenv("GROQ_API_KEY"),
        max_retries=5,
        
    ),
    "deepinfra": ProviderConfig(
        model_name="Qwen/Qwen2.5-72B-Instruct",
        api_key=os.getenv("DEEPINFRA_API_KEY"),
        max_retries=5,
    ),
}

# %%
client = LLMInferenceClient(providers)

# %%
OUTPUT_FILE = "./data/extracted_principles.jsonl"
CHECKPOINT_FILE = "./data/checkpoint_ids.txt"

# %%
async def process_sample(
    client,
    sample: Dict,
    index: int,
    total: int,
    processed_ids: Set[str],
    output_file: str,
    checkpoint_file: str,
    prompt_template: str,
    provider: str = 'deepinfra',
    verbose: bool = False
):
    """Process a single sample asynchronously."""
    try:
        # Unique ID for checkpointing
        p_id = str(sample.get('prompt_id', f"idx_{index}"))
        
        # SKIP if already done
        if p_id in processed_ids:
            if verbose:
                print(f"[{index+1}/{total}] Skipping ID {p_id} (already processed)")
            return {"status": "skipped", "reason": "already_processed"}
            
        feedback_text = sample.get('feedback1', '')
        
        # Handle if feedback is a list (multiple feedbacks)
        if isinstance(feedback_text, list):
            # Join all feedbacks with newlines or process each separately
            feedback_text = '\n\n'.join(str(f) for f in feedback_text if f)
        
        if not feedback_text:
            if verbose:
                print(f"[{index+1}/{total}] Skipping ID {p_id} (no feedback)")
            return {"status": "skipped", "reason": "no_feedback"}

        print(f"[{index+1}/{total}] Processing ID: {p_id}...", end="", flush=True)
        
        # Call API (this is where concurrency happens!)
        extracted_json = await client.infer(
            feedback_text, 
            prompt_template, 
            provider=provider
        )
        
        if not extracted_json:
            print(f" API returned None/empty")
            return {"status": "error", "error": "API returned empty"}
        
        # Prepare Result
        result_entry = {
            "prompt_id": p_id,
            "original_feedback": feedback_text,
            "extracted_json": extracted_json
        }
        
        # Save immediately
        save_success(result_entry, p_id, output_file, checkpoint_file)
        
        print(" Done.")
        return {"status": "success", "p_id": p_id}
        
    except Exception as e:
        print(f"\n[ERROR] Sample {index}: {type(e).__name__}: {str(e)}")
        import traceback
        traceback.print_exc()
        return {"status": "error", "error": str(e)}

# %%
async def main_concurrent(
    client,
    ds,
    checkpoint_file: str,
    output_file: str,
    prompt_template: str,
    provider: str = 'deepinfra',
    batch_size: int = 10  # Process N samples concurrently
):
    """Main async processing function with concurrent batching."""
    processed_ids = load_processed_ids(checkpoint_file)
    print(f"Resuming... {len(processed_ids)} samples already processed.")
    
    total_samples = len(ds)
    
    # Process in batches to avoid overwhelming the API
    for batch_start in range(0, total_samples, batch_size):
        batch_end = min(batch_start + batch_size, total_samples)
        batch = ds.select(range(batch_start, batch_end))
        
        print(f"\n=== Processing batch {batch_start//batch_size + 1} ({batch_start+1}-{batch_end}/{total_samples}) ===")
        
        # Create tasks for concurrent processing
        tasks = [
            process_sample(
                client=client,
                sample=sample,
                index=batch_start + i,
                total=total_samples,
                processed_ids=processed_ids,
                output_file=output_file,
                checkpoint_file=checkpoint_file,
                prompt_template=prompt_template,
                provider=provider
            )
            for i, sample in enumerate(batch)
        ]
        
        # Run all tasks concurrently
        results = await asyncio.gather(*tasks, return_exceptions=True)
        
        # Update processed_ids for next batch
        processed_ids = load_processed_ids(checkpoint_file)
        
        # Optional: Print batch summary
        successful = sum(1 for r in results if r is not None and not isinstance(r, Exception))
        print(f"Batch complete: {successful}/{len(tasks)} successful")

        await asyncio.sleep(1)   # Rate limiting between batches

# %%
await main_concurrent(
    client=client,
    ds=ds,
    checkpoint_file=CHECKPOINT_FILE,
    output_file=OUTPUT_FILE,
    prompt_template=PROMPT_TEMPLATE,
    provider='deepinfra',
    batch_size=100,
)
# Out:
# Resuming... 10248 samples already processed.
#
# === Processing batch 1 (1-100/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 2 (101-200/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 3 (201-300/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 4 (301-400/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 5 (401-500/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 6 (501-600/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 7 (601-700/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 8 (701-800/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 9 (801-900/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 10 (901-1000/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 11 (1001-1100/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 12 (1101-1200/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 13 (1201-1300/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 14 (1301-1400/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 15 (1401-1500/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 16 (1501-1600/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 17 (1601-1700/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 18 (1701-1800/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 19 (1801-1900/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 20 (1901-2000/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 21 (2001-2100/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 22 (2101-2200/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 23 (2201-2300/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 24 (2301-2400/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 25 (2401-2500/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 26 (2501-2600/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 27 (2601-2700/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 28 (2701-2800/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 29 (2801-2900/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 30 (2901-3000/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 31 (3001-3100/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 32 (3101-3200/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 33 (3201-3300/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 34 (3301-3400/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 35 (3401-3500/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 36 (3501-3600/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 37 (3601-3700/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 38 (3701-3800/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 39 (3801-3900/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 40 (3901-4000/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 41 (4001-4100/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 42 (4101-4200/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 43 (4201-4300/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 44 (4301-4400/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 45 (4401-4500/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 46 (4501-4600/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 47 (4601-4700/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 48 (4701-4800/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 49 (4801-4900/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 50 (4901-5000/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 51 (5001-5100/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 52 (5101-5200/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 53 (5201-5300/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 54 (5301-5400/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 55 (5401-5500/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 56 (5501-5600/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 57 (5601-5700/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 58 (5701-5800/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 59 (5801-5900/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 60 (5901-6000/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 61 (6001-6100/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 62 (6101-6200/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 63 (6201-6300/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 64 (6301-6400/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch 65 (6401-6500/38782) ===
# Batch complete: 100/100 successful
#
# === Processing batch
[11884/38782] Processing ID: idx_11883...[11885/38782] Processing ID: idx_11884...[11886/38782] Processing ID: idx_11885...[11887/38782] Processing ID: idx_11886...[11888/38782] Processing ID: idx_11887...[11889/38782] Processing ID: idx_11888...[11890/38782] Processing ID: idx_11889...[11891/38782] Processing ID: idx_11890...[11892/38782] Processing ID: idx_11891...[11893/38782] Processing ID: idx_11892...[11894/38782] Processing ID: idx_11893...[11895/38782] Processing ID: idx_11894...[11896/38782] Processing ID: idx_11895...[11897/38782] Processing ID: idx_11896...[11898/38782] Processin ...
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#  Done.
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
#
# [!] DeepInfra Error: Connection error.
#  API returned None/empty
